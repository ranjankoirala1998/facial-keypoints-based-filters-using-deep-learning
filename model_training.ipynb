# %% [markdown]
# ## import necesary libraries and modules

# %%
import numpy as np
from get_data import get_train, get_test, plot_sample
import matplotlib.pyplot as plt
# %matplotlib inline

from keras import layers, callbacks, utils, applications, optimizers
from keras.models import Sequential, Model, load_model

# %% [markdown]
# ## load train and test data

# %%
train_images, train_keypoints = get_train()
test_images = get_test()

# %% [markdown]
# ## define a model

# %%
# model = Sequential()

# pretrained_model = applications.MobileNet(input_shape=(96, 96, 3), include_top=False, weights='imagenet')
# pretrained_model.trainable = True

# model.add(layers.Convolution2D(3, (1, 1), padding='same', input_shape=(96,96,1)))
# model.add(layers.LeakyReLU(alpha = 0.1))
# model.add(pretrained_model)
# model.add(layers.GlobalAveragePooling2D())
# model.add(layers.Dropout(0.1))
# model.add(layers.Dense(30))
# model.summary()

# %%
# es = callbacks.EarlyStopping(
#     monitor='loss', patience=30, verbose=1, mode='min', baseline=None, restore_best_weights=True
# )

# rlp = callbacks.ReduceLROnPlateau(
#     monitor='val_loss', factor=0.5, patience=5, min_lr=1e-15, mode='min', verbose=1
# )

# %%
# model.compile(loss='mean_absolute_error', optimizer='adam', metrics = ['accuracy'])

# %%
# NUM_EPOCHS = 100
# BATCH_SIZE = 128
# history = model.fit(train_images, train_keypoints, epochs=NUM_EPOCHS, batch_size=BATCH_SIZE, validation_split=0.15, callbacks=[es, rlp])

# %%
# # summarize history for accuracy
# plt.plot(history.history['accuracy'])
# plt.plot(history.history['val_accuracy'])
# plt.title('Accuracy vs Epoch')
# plt.ylabel('Accuracy')
# plt.xlabel('Epochs')
# plt.legend(['train', 'validation'], loc='upper left')
# plt.show()

# # summarize history for loss
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title('Loss vs Epoch')
# plt.ylabel('Loss')
# plt.xlabel('Epochs')
# plt.legend(['train', 'validation'], loc='upper left')
# plt.show()

# %%
final_model = load_model('model.h5')

# %%
predict = final_model.predict(test_images)

# %%
i = 6

fig, axis = plt.subplots()
plot_sample(test_images[i], predict[i], axis, "Sample Test Image and Predicted Keypoints")
